# %%
class Car:
    pass

audi = Car()
bmw = Car()

print(type(audi))
print(audi)
# Out:
# <class '__main__.Car'>
# <__main__.Car object at 0x00000250E8EF2AA0>

# %%
# Incorrect Method!!
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
class Dog:
    def __init__(self,name,age): # Constructor
        self.name = name
        self.age = age
    def bark(self):
        print(f"{self.name} says whoooof!!!")

dog1 = Dog("Tommy",2)
dog1.bark()
# Out:
# Tommy says whoooof!!!

# %%
 # Another example using Bank Account

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance = balance
        pass
    def deposite(self,amount):
        self.balance += amount
        print(f'New Balance is: {self.balance}')
    def withdraw(self,amount):
        if amount > self.balance:
            print("Insufficient Funds!")
            return
        else:
            self.balance -= amount
            print(f'New Balance is: {self.balance}')
    def get_balance(self):
        return self.balance


a1 = BankAccount("Tirth")
a1.deposite(1000)
a1.get_balance()
a1.withdraw(2000)
# Out:
# New Balance is: 1000
# Insufficient Funds!
