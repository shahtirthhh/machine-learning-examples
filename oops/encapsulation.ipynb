# %%
class Person:
    def __init__(self,name,age,gender,employed=False):
        self.__name = name #private
        self.__age = age #private
        self._employed = employed #protected
        self.gender = gender # public
